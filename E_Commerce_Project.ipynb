# %%
# Link to the dataset: https://www.kaggle.com/datasets/thedevastator/unlock-profits-with-e-commerce-sales-data?resource=download
import os
import zipfile

zip_file_path = r'D:\Learning\Project\E-Commerce Project\Amazon Sale Report.csv.zip'
extract_file_path = r'D:\Learning\Project\E-Commerce Project'
extracted_file = os.path.join(extract_file_path, 'Amazon Sale Report.csv')

# Check if the extracted file already exists
if os.path.exists(extracted_file):
    print("File already present.")
else:
    with zipfile.ZipFile(zip_file_path, 'r') as un_zip:
        un_zip.extractall(extract_file_path)
        print("Zip file extracted successfully.")
# Out:
# File already present.

# %%
# Load the CSV file into python
import pandas as pd

file_path = r'D:\Learning\Project\E-Commerce Project\Amazon Sale Report.csv'
df = pd.read_csv(file_path)

# Display some information about the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 128975 entries, 0 to 128974
# Data columns (total 24 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   index               128975 non-null  int64
#  1   Order ID            128975 non-null  object
#  2   Date                128975 non-null  object
#  3   Status              128975 non-null  object
#  4   Fulfilment          128975 non-null  object
#  5   Sales Channel       128975 non-null  object
#  6   ship-service-level  128975 non-null  object
#  7   Style               128975 non-null  object
#  8   SKU                 128975 non-null  object
#  9   Category            128975 non-null  object
#  10  Size                128975 non-null  object
#  11  ASIN                128975 non-null  object
#  12  Courier Status      122103 non-null  object
#  13  Qty                 128975 non-null  int64
#  14  currency            121180 non-null  object
# ...

# %%
# Check if the head of the data
df.head()
# Out:
#    index             Order ID      Date                        Status  \
# 0      0  405-8078784-5731545  04-30-22                     Cancelled
# 1      1  171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2      2  404-0687676-7273146  04-30-22                       Shipped
# 3      3  403-9615377-8133951  04-30-22                     Cancelled
# 4      4  407-1069790-7240320  04-30-22                       Shipped
#
#   Fulfilment Sales Channel  ship-service-level    Style              SKU  \
# 0   Merchant      Amazon.in           Standard   SET389   SET389-KR-NP-S
# 1   Merchant      Amazon.in           Standard  JNE3781  JNE3781-KR-XXXL
# 2     Amazon      Amazon.in          Expedited  JNE3371    JNE3371-KR-XL
# 3   Merchant      Amazon.in           Standard    J0341       J0341-DR-L
# 4     Amazon      Amazon.in          Expedited  JNE3671  JNE3671-TU-XXXL
#
#         Category  ... currency  Amount    ship-city   ship-state  \
# ...

# %%
# Now this data should be cleaned and one of the first step is to remove all the irrelevant columns
df_cleaned = df.drop(columns = ['index', 'Unnamed: 22'])

# %%
df_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 128975 entries, 0 to 128974
# Data columns (total 22 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   Order ID            128975 non-null  object
#  1   Date                128975 non-null  object
#  2   Status              128975 non-null  object
#  3   Fulfilment          128975 non-null  object
#  4   Sales Channel       128975 non-null  object
#  5   ship-service-level  128975 non-null  object
#  6   Style               128975 non-null  object
#  7   SKU                 128975 non-null  object
#  8   Category            128975 non-null  object
#  9   Size                128975 non-null  object
#  10  ASIN                128975 non-null  object
#  11  Courier Status      122103 non-null  object
#  12  Qty                 128975 non-null  int64
#  13  currency            121180 non-null  object
#  14  Amount              121180 non-null  float64
# ...

# %%
# Checking and removing any duplicates found in the data
duplicate_data = df_cleaned[df_cleaned.duplicated()]
print(duplicate_data)
duplicate_sum = df_cleaned.duplicated().sum()
print('Total duplicate values are: {}'.format(duplicate_sum))
# Out:
#                   Order ID      Date     Status Fulfilment Sales Channel   \
# 30661  406-0372545-6086735  04-12-22  Cancelled     Amazon      Amazon.in
# 41292  408-0373839-4433120  04-05-22  Cancelled     Amazon      Amazon.in
# 79845  171-9628368-5329958  05-07-22  Cancelled     Amazon      Amazon.in
# 85791  171-3249942-2207542  05-03-22    Shipped     Amazon      Amazon.in
# 86419  405-8669298-3850736  05-03-22    Shipped     Amazon      Amazon.in
# 98955  407-4853873-4978725  06-22-22    Shipped     Amazon      Amazon.in
#
#       ship-service-level    Style              SKU Category Size  ... Qty  \
# 30661          Expedited   SET197   SET197-KR-NP-L      Set    L  ...   0
# 41292          Expedited  JNE3501     JNE3501-KR-M    kurta    M  ...   0
# 79845          Expedited    J0329       J0329-KR-L    kurta    L  ...   0
# 85791          Expedited   SET323  SET323-KR-NP-XL      Set   XL  ...   1
# 86419          Expedited  MEN5025  MEN5025-KR-XXXL    kurta  3XL  ...   1
# ...

# %%
# Now these duplicate values need to be removed
df_cleaned_dups = df_cleaned.drop_duplicates()

# %%
# Lets see if there are any duplicated values in the dataset
print('Checking for duplicate values after removing them: {} Found'.format(df_cleaned_dups.duplicated().sum()))
# Out:
# Checking for duplicate values after removing them: 0 Found

# %%
# Check for missing values in each column
missing_values = df_cleaned_dups.isnull().sum()

# Display columns with their corresponding count of missing values
print(missing_values)
# Out:
# Order ID                  0
# Date                      0
# Status                    0
# Fulfilment                0
# Sales Channel             0
# ship-service-level        0
# Style                     0
# SKU                       0
# Category                  0
# Size                      0
# ASIN                      0
# Courier Status         6872
# Qty                       0
# currency               7792
# Amount                 7792
# ship-city                33
# ship-state               33
# ship-postal-code         33
# ship-country             33
# promotion-ids         49150
# B2B                       0
# fulfilled-by          89692
# dtype: int64

# %%
# There are quite a few null values in the columns now lets replace the values or remove those values if the row can't be used with that missing value like amount or currency
df_cleaned_rm_rows = df_cleaned_dups.dropna(subset=['Amount', 'currency', 'ship-city', 'ship-state', 'ship-postal-code', 'ship-country'])

# Check for missing values after deleting na values
missing_values_1 = df_cleaned_rm_rows.isnull().sum()

# Display columns with their corresponding count of missing values
print(missing_values_1)
# Out:
# Order ID                  0
# Date                      0
# Status                    0
# Fulfilment                0
# Sales Channel             0
# ship-service-level        0
# Style                     0
# SKU                       0
# Category                  0
# Size                      0
# ASIN                      0
# Courier Status         5133
# Qty                       0
# currency                  0
# Amount                    0
# ship-city                 0
# ship-state                0
# ship-postal-code          0
# ship-country              0
# promotion-ids         41691
# B2B                       0
# fulfilled-by          83618
# dtype: int64

# %%
# Replace the rest of the missing values to unkown
df_cleaned_rm_rows.loc[:,'Courier Status'] = df_cleaned_rm_rows['Courier Status'].fillna('Unknown')
df_cleaned_rm_rows.loc[:,'promotion-ids'] = df_cleaned_rm_rows['promotion-ids'].fillna('No Promotion Used')
df_cleaned_rm_rows.loc[:,'fulfilled-by'] = df_cleaned_rm_rows['fulfilled-by'].fillna('Unknown')

# %%
# Now check for the missing values
missing_values_2 = df_cleaned_rm_rows.isnull().sum()

# Display columns with their corresponding count of missing values
print(missing_values_2)
# Out:
# Order ID              0
# Date                  0
# Status                0
# Fulfilment            0
# Sales Channel         0
# ship-service-level    0
# Style                 0
# SKU                   0
# Category              0
# Size                  0
# ASIN                  0
# Courier Status        0
# Qty                   0
# currency              0
# Amount                0
# ship-city             0
# ship-state            0
# ship-postal-code      0
# ship-country          0
# promotion-ids         0
# B2B                   0
# fulfilled-by          0
# dtype: int64

# %%
# We eliminated duplicate and missing values and before using it in SQL lets check if the data types are correct
print(df_cleaned_rm_rows.dtypes)
# Out:
# Order ID               object
# Date                   object
# Status                 object
# Fulfilment             object
# Sales Channel          object
# ship-service-level     object
# Style                  object
# SKU                    object
# Category               object
# Size                   object
# ASIN                   object
# Courier Status         object
# Qty                     int64
# currency               object
# Amount                float64
# ship-city              object
# ship-state             object
# ship-postal-code      float64
# ship-country           object
# promotion-ids          object
# B2B                      bool
# fulfilled-by           object
# dtype: object

# %%
# Convert 'Date' column to datetime
df_cleaned_rm_rows['Date'] = pd.to_datetime(df_cleaned_rm_rows['Date'], errors = 'coerce')

print(df_cleaned_rm_rows.dtypes)
# Out:
# Order ID                      object
# Date                  datetime64[ns]
# Status                        object
# Fulfilment                    object
# Sales Channel                 object
# ship-service-level            object
# Style                         object
# SKU                           object
# Category                      object
# Size                          object
# ASIN                          object
# Courier Status                object
# Qty                            int64
# currency                      object
# Amount                       float64
# ship-city                     object
# ship-state                    object
# ship-postal-code             float64
# ship-country                  object
# promotion-ids                 object
# B2B                             bool
# fulfilled-by                  object
# dtype: object
# ...

# %%
# Extracting Year and month from the data
df_cleaned_rm_rows.loc[:, 'Year'] = df_cleaned_rm_rows['Date'].dt.year
df_cleaned_rm_rows.loc[:, 'Month'] = df_cleaned_rm_rows['Date'].dt.month
# Out:
# C:\Users\teja2\AppData\Local\Temp\ipykernel_28076\2759535099.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned_rm_rows.loc[:, 'Year'] = df_cleaned_rm_rows['Date'].dt.year
# C:\Users\teja2\AppData\Local\Temp\ipykernel_28076\2759535099.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned_rm_rows.loc[:, 'Month'] = df_cleaned_rm_rows['Date'].dt.month

# %%
# Now let's see our final cleaned data
df_cleaned_rm_rows
# Out:
#                    Order ID       Date                        Status  \
# 0       405-8078784-5731545 2022-04-30                     Cancelled
# 1       171-9198151-1101146 2022-04-30  Shipped - Delivered to Buyer
# 2       404-0687676-7273146 2022-04-30                       Shipped
# 3       403-9615377-8133951 2022-04-30                     Cancelled
# 4       407-1069790-7240320 2022-04-30                       Shipped
# ...                     ...        ...                           ...
# 128970  406-6001380-7673107 2022-05-31                       Shipped
# 128971  402-9551604-7544318 2022-05-31                       Shipped
# 128972  407-9547469-3152358 2022-05-31                       Shipped
# 128973  402-6184140-0545956 2022-05-31                       Shipped
# 128974  408-7436540-8728312 2022-05-31                       Shipped
#
#        Fulfilment Sales Channel  ship-service-level    Style              SKU  \
# ...

# %%
output_path = r'D:\Learning\Project\E-Commerce Project\Cleaned Amazon Sale Report.csv'
if os.path.exists(output_path):
    print("Output csv file already exists")
else:
    df_cleaned_rm_rows.to_csv(r'D:\Learning\Project\E-Commerce Project\Cleaned Amazon Sale Report.csv', index = False)
# Out:
# Output csv file already exists
